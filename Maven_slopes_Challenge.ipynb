# %%
pip install chardet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import chardet
import datetime as dt
# %matplotlib inline

# %%
file='C:/Users/Srividya Shashidhara/Documents/Vidya_Projects/Kaggle/resorts.csv'


import chardet
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.7290972263117602, 'language': ''}

# %%
df_resorts = pd.read_csv(file,encoding='Windows-1252')
df_resorts.head()
# Out:
#    ID                        Resort   Latitude   Longitude  Country  \
# 0   1                      Hemsedal  60.928244    8.383487   Norway
# 1   2              Geilosiden Geilo  60.534526    8.206372   Norway
# 2   3                          Golm  47.057810    9.828167  Austria
# 3   4  Red Mountain Resort-Rossland  49.105520 -117.846280   Canada
# 4   5                       Hafjell  61.230369   10.529014   Norway
#
#        Continent  Price            Season  Highest point  Lowest point  ...  \
# 0         Europe     46    November - May           1450           620  ...
# 1         Europe     44  November - April           1178           800  ...
# 2         Europe     48  December - April           2110           650  ...
# 3  North America     60  December - April           2075          1185  ...
# 4         Europe     45  November - April           1030           195  ...
#
#    Snow cannons  Surface lifts  Chair lifts  Gondola lifts  Total lifts  \
# ...

# %%
df_resorts.describe()
# Out:
#                ID    Latitude   Longitude       Price  Highest point  \
# count  499.000000  499.000000  499.000000  499.000000     499.000000
# mean   250.000000   43.205684   -6.006784   48.721443    2160.589178
# std    144.193157   15.975790   59.990459   21.718733     774.339805
# min      1.000000  -45.054960 -149.740657    0.000000     163.000000
# 25%    125.500000   43.672650    1.380975   36.000000    1594.000000
# 50%    250.000000   46.347316    8.206372   45.000000    2175.000000
# 75%    374.500000   47.327089   12.429237   54.000000    2700.000000
# max    499.000000   67.784406  176.876668  141.000000    3914.000000
#
#        Lowest point  Beginner slopes  Intermediate slopes  Difficult slopes  \
# count    499.000000       499.000000           499.000000        499.000000
# mean    1200.631263        31.819639            37.921844         16.164329
# std      596.142294        47.401764            44.358524         20.115855
# ...

# %%
x=df_resorts['Price'].min()
x
# Out:
# 0

# %%
df_resorts.nsmallest(20,'Price')
# Out:
#       ID                                    Resort   Latitude   Longitude  \
# 195  196                                  Perisher -36.396167  148.408582
# 234  235                          Yellowstone Club  45.668198 -111.067446
# 334  335                                 Pragelato  45.016217    6.942453
# 348  349                             Uludag?-Bursa  40.070529   29.222010
# 368  369  Palando?ken-Ejder 3200 World Ski Center-  39.543016   42.915247
# 386  387                              High1 Resort  37.207294  128.824816
# 389  390                            Alpika Service  43.667196   40.246821
# 474  475                       Sun Mountain-Yabuli  44.929398  128.604393
# 494  495                                   Puigmal  42.395007    2.108883
# 290  291                                   Gudauri  42.476558   44.477029
# 314  315                           Erciyes-Kayseri  38.532740   35.450225
# 475  476                   Jochgrimm-Passo Oclini-  46.347316   11.451535
# ...

# %%
y=df_resorts['Price'].max()
y
# Out:
# 141

# %%
sns.displot(df_resorts['Price'],kde=True,bins=5,color='blue')

# %%
sns.boxplot(y='Price',data=df_resorts,palette='rainbow')
# Out:
# <AxesSubplot:ylabel='Price'>

# %%
sns.displot(df_resorts['Beginner slopes'],kde=True,bins=5,color='blue')

# %%
sns.displot(df_resorts['Intermediate slopes'],kde=True,bins=5,color='blue')

# %%
sns.heatmap(df_resorts.corr(),cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
df_resorts.corr().sort_values('Price',ascending=False)
# Out:
#                            ID  Latitude  Longitude     Price  Highest point  \
# Price               -0.384625 -0.165974  -0.515617  1.000000       0.380610
# Difficult slopes    -0.447321 -0.024736  -0.392631  0.572100       0.487343
# Highest point       -0.393581 -0.171559  -0.255127  0.380610       1.000000
# Lowest point        -0.224879 -0.284497  -0.383648  0.368589       0.782016
# Intermediate slopes -0.471358  0.032010  -0.076903  0.312376       0.416730
# Total slopes        -0.477408  0.041939  -0.096211  0.307344       0.419399
# Longest run         -0.255469  0.043443  -0.111805  0.262453       0.279931
# Chair lifts         -0.397569 -0.006016   0.042568  0.234412       0.299979
# Lift capacity       -0.399214  0.056284   0.086267  0.152454       0.278586
# Gondola lifts       -0.332208  0.075983   0.122621  0.122865       0.300400
# Beginner slopes     -0.385030  0.069791   0.033842  0.118946       0.295720
# ...

# %%
sns.displot(df_resorts['Highest point'],kde=True,bins=8,color='blue')

# %%
file_2='C:/Users/Srividya Shashidhara/Documents/Vidya_Projects/PowerBI/Ski_resorts_maven/Ski+Resorts/season_month_export.csv'


import chardet
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.7290972263117602, 'language': ''}

# %%
df_season_month = pd.read_csv(file_2)
df_season_month.head()
# Out:
#    resorts_ID          SES_ID  SES_NAME  SES_Num  resorts_Latitude  \
# 0           1  November - May     April        4         60.928244
# 1           1  November - May  December       12         60.928244
# 2           1  November - May  February        2         60.928244
# 3           1  November - May   January        1         60.928244
# 4           1  November - May     March        3         60.928244
#
#    resorts_Longitude
# 0           8.383487
# 1           8.383487
# 2           8.383487
# 3           8.383487
# 4           8.383487

# %%
file_3='C:/Users/Srividya Shashidhara/Documents/Vidya_Projects/PowerBI/Ski_resorts_maven/Ski+Resorts/snow.csv'


import chardet
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.7290972263117602, 'language': ''}

# %%
df_snow = pd.read_csv(file_3)
df_snow.head()
# Out:
#         Month  Latitude  Longitude    Snow
# 0  2022-12-01    63.125     68.875   95.28
# 1  2022-12-01    63.125     69.125  100.00
# 2  2022-12-01    63.125     69.375  100.00
# 3  2022-12-01    63.125     69.625  100.00
# 4  2022-12-01    63.125     69.875  100.00

# %%
df_snow['month_num']=pd.DatetimeIndex(df_snow['Month']).month

# %%
df_snow.head()
# Out:
#         Month  Latitude  Longitude    Snow  month_num
# 0  2022-12-01    63.125     68.875   95.28         12
# 1  2022-12-01    63.125     69.125  100.00         12
# 2  2022-12-01    63.125     69.375  100.00         12
# 3  2022-12-01    63.125     69.625  100.00         12
# 4  2022-12-01    63.125     69.875  100.00         12

# %%
df_merge=pd.merge(df_season_month,  df_snow[(df_season_month['resorts_Latitude'].between(df_snow['Latitude']-0.125, df_snow['Latitude']+0.125 )) & (df_season_month['resorts_Longitude'].between(df_snow['Longitude']-0.125, df_snow['Longitude']+0.125 ))] , how='left',left_on='SES_Num' , right_on='month_num')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df_merge=pd.merge(df_season_month,  df_snow[(df_season_month['resorts_Latitude'].between(df_snow['Latitude']-0.125, df_snow['Latitude']+0.125 )) & (df_season_month['resorts_Longitude'].between(df_snow['Longitude']-0.125, df_snow['Longitude']+0.125 ))] , how='left',left_on='SES_Num' , right_on='month_num')
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5226, in Series.between(self, left, right, inclusive)
#    5224         inclusive = "neither"
#    5225 if inclusive == "both":
# -> 5226     lmask = self >= left
#    5227     rmask = self <= right
#    5228 elif inclusive == "left":
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
# ...

# %%
result=df_season_month.merge(df_snow,how='left',left_on='SES_Num' , right_on='month_num').loc[
    lambda df: (
        (df['resorts_Latitude'].between(df['Latitude'] - 0.125, df['Latitude'] + 0.125)) &
    (df['resorts_Longitude'].between(df['Longitude'] - 0.125, df['Longitude'] + 0.125))
    )].drop_duplicates()
result
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 result=df_season_month.merge(df_snow,how='left',left_on='SES_Num' , right_on='month_num').loc[
#       2     lambda df: (
#       3         (df['resorts_Latitude'].between(df['Latitude'] - 0.125, df['Latitude'] + 0.125)) &
#       4     (df['resorts_Longitude'].between(df['Longitude'] - 0.125, df['Longitude'] + 0.125))
#       5     )].drop_duplicates()
#       6 result
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# ...
